# %% [markdown]
# # Credit Risk Modeling

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.options.display.float_format = '{:.2f}'.format

# %%
df_customers = pd.read_csv(r"E:\Code Basics\Machine Learning\16 Project 2 Credit Risk Modeling (Classification)\16.4 Data Collection\DataCollection_Resources\customers.csv")
df_loan = pd.read_csv(r"E:\Code Basics\Machine Learning\16 Project 2 Credit Risk Modeling (Classification)\16.4 Data Collection\DataCollection_Resources\loans.csv")
df_bureau = pd.read_csv(r"E:\Code Basics\Machine Learning\16 Project 2 Credit Risk Modeling (Classification)\16.4 Data Collection\DataCollection_Resources\bureau_data.csv")

# %%
df_customers.shape, df_loan.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001

# %%
df_loan.head(3)
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False

# %%
df_bureau.head(3)
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58

# %%
df = pd.merge(df_customers, df_loan, on="cust_id")
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
#
# [3 rows x 26 columns]

# %%
df = pd.merge(df, df_bureau)
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
#
# [3 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %%
df.describe()
# Out:
#            age      income  number_of_dependants  years_at_current_address  \
# count 50000.00    50000.00              50000.00                  50000.00
# mean     39.55  2640897.50                  1.94                     16.02
# std       9.85  2629441.06                  1.54                      8.93
# min      18.00        0.00                  0.00                      1.00
# 25%      33.00   803000.00                  0.00                      8.00
# 50%      40.00  1892000.00                  2.00                     16.00
# 75%      46.00  3332250.00                  3.00                     24.00
# max      70.00 11999000.00                  5.00                     31.00
#
#         zipcode  sanction_amount  loan_amount  processing_fee        gst  \
# count  50000.00         50000.00     50000.00        50000.00   50000.00
# mean  419090.86       4704827.52   3999678.80        80494.71  719942.18
# std   168982.67       6267276.39   5376552.03       117312.26  967779.37
# min   110001.00             0.00         0.00            0.00       0.00
# 25%   302001.00       1147000.00    967000.00        19340.00  174060.00
# 50%   400001.00       2656000.00   2240000.00        44800.00  403200.00
# 75%   560001.00       5172250.00   4611000.00        92240.00  829980.00
# max   700001.00      52175000.00  47819000.00      5698029.90 8607420.00
#
#        net_disbursement  loan_tenure_months  principal_outstanding  \
# count          50000.00            50000.00               50000.00
# mean         3199743.04               25.94             1337636.04
# std          4301241.63               12.43             1214713.89
# min                0.00                6.00                  -1.00
# 25%           773600.00               16.00              424799.00
# 50%          1792000.00               24.00             1002309.00
# 75%          3688800.00               35.00             1790751.00
# max         38255200.00               59.00             5000000.00
#
#        bank_balance_at_application  number_of_open_accounts  \
# count                     50000.00                 50000.00
# mean                     989126.38                     2.50
# std                     1046071.89                     1.12
# min                           0.00                     1.00
# 25%                      287007.50                     1.00
# 50%                      668525.00                     3.00
# 75%                     1238667.00                     4.00
# max                     7846643.00                     4.00
#
#        number_of_closed_accounts  total_loan_months  delinquent_months  \
# count                   50000.00           50000.00           50000.00
# mean                        1.00              76.13               4.88
# std                         0.81              43.76               5.85
# min                         0.00               1.00               0.00
# 25%                         0.00              42.00               0.00
# 50%                         1.00              71.00               3.00
# 75%                         2.00             107.00               9.00
# max                         2.00             223.00              24.00
#
#        total_dpd  enquiry_count  credit_utilization_ratio
# count   50000.00       50000.00                  50000.00
# mean       26.86           5.01                     43.36
# std        32.83           2.03                     29.36
# min         0.00           1.00                      0.00
# 25%         0.00           4.00                     18.00
# 50%        14.00           5.00                     39.00
# 75%        46.00           6.00                     67.00
# max       171.00           9.00                     99.00

# %%
df["default"] = df["default"].astype(int)

# %%
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10       0                       1
# 1  ...     2019-07-24            2019-08-15       0                       3
# 2  ...     2019-07-24            2019-08-21       0                       2
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
#
# [3 rows x 33 columns]

# %%
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %% [markdown]
# ### Train Test Split

# %% [markdown]
# We perform train test split before doing EDA to prevent data leakage. We don't want test set (which is part of the entire dataset) to influence EDA or any decisions on feature engineering.

# %%
X = df.drop("default", axis=1)
y = df["default"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)

df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_train.head()
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
# 9040   C09041   42      M        Married          Salaried   1500000
# 13077  C13078   58      M        Married     Self-Employed   1817000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
# 9040                      2       Mortgage                        30
# 13077                     4          Owned                        29
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
# 43675    Chennai  ...     2023-12-04            2023-12-29
# 9040   Bangalore  ...     2020-06-18            2020-07-07
# 13077       Pune  ...     2020-11-12            2020-12-07
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# 32495                       3                         1               160
# 43675                       1                         1                54
# 9040                        3                         0                76
# 13077                       1                         2                60
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 12746                 20        118              4                        36
# 32495                 10         62              5                         5
# 43675                 12         67              4                         0
# 9040                   0          0              8                        87
# 13077                  0          0              1                        71
#
#        default
# 12746        0
# 32495        0
# 43675        0
# 9040         0
# 13077        0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Data Cleaning

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train["residence_type"].unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
df_train["residence_type"].mode()
# Out:
# 0    Owned
# Name: residence_type, dtype: object

# %%
df_train["residence_type"].fillna("Owned", inplace=True)

# do the same with test dataset
df_test["residence_type"].fillna("Owned", inplace=True)

# %%
df_train["residence_type"].unique(), df_test["residence_type"].unique()
# Out:
# (array(['Owned', 'Mortgage', 'Rented'], dtype=object),
#  array(['Owned', 'Mortgage', 'Rented'], dtype=object))

# %%
df_train.describe()
# Out:
#            age      income  number_of_dependants  years_at_current_address  \
# count 37500.00    37500.00              37500.00                  37500.00
# mean     39.54  2633326.16                  1.94                     16.00
# std       9.86  2623780.52                  1.54                      8.92
# min      18.00        0.00                  0.00                      1.00
# 25%      33.00   802000.00                  0.00                      8.00
# 50%      39.00  1885000.00                  2.00                     16.00
# 75%      46.00  3326250.00                  3.00                     24.00
# max      70.00 11999000.00                  5.00                     31.00
#
#         zipcode  sanction_amount  loan_amount  processing_fee        gst  \
# count  37500.00         37500.00     37500.00        37500.00   37500.00
# mean  418866.25       4699691.57   3996067.73        80290.68  719292.19
# std   169035.02       6257832.98   5371862.29       113128.14  966935.21
# min   110001.00             0.00         0.00            0.00       0.00
# 25%   302001.00       1142000.00    961000.00        19220.00  172980.00
# 50%   400001.00       2644000.00   2230000.00        44600.00  401400.00
# 75%   560001.00       5178000.00   4619000.00        92420.00  831420.00
# max   700001.00      52175000.00  47819000.00      5293543.52 8607420.00
#
#        net_disbursement  ...  principal_outstanding  \
# count          37500.00  ...               37500.00
# mean         3196854.19  ...             1333819.51
# std          4297489.83  ...             1213674.44
# min                0.00  ...                  -1.00
# 25%           768800.00  ...              422197.50
# 50%          1784000.00  ...              997427.50
# 75%          3695200.00  ...             1784879.00
# max         38255200.00  ...             5000000.00
#
#        bank_balance_at_application  number_of_open_accounts  \
# count                     37500.00                 37500.00
# mean                     986298.87                     2.50
# std                     1043145.01                     1.12
# min                           0.00                     1.00
# 25%                      287040.25                     1.00
# 50%                      665014.50                     3.00
# 75%                     1234062.75                     4.00
# max                     7846643.00                     4.00
#
#        number_of_closed_accounts  total_loan_months  delinquent_months  \
# count                   37500.00           37500.00           37500.00
# mean                        1.00              76.11               4.84
# std                         0.81              43.77               5.84
# min                         0.00               1.00               0.00
# 25%                         0.00              42.00               0.00
# 50%                         1.00              71.00               3.00
# 75%                         2.00             107.00               8.00
# max                         2.00             223.00              24.00
#
#        total_dpd  enquiry_count  credit_utilization_ratio  default
# count   37500.00       37500.00                  37500.00 37500.00
# mean       26.67           5.01                     43.42     0.09
# std        32.78           2.03                     29.39     0.28
# min         0.00           1.00                      0.00     0.00
# 25%         0.00           4.00                     18.00     0.00
# 50%        13.00           5.00                     39.00     0.00
# 75%        46.00           6.00                     67.00     0.00
# max       171.00           9.00                     99.00     1.00
#
# [8 rows x 21 columns]

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
cols_numerical = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

cols_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                    'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %% [markdown]
# ### Box Plot Visualize Outliers

# %%
num_plots = len(cols_numerical)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(cols_numerical):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = len(cols_numerical)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(cols_numerical):
    sns.histplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outlier Removal: Processing Fees

# %%
df_train["processing_fee"].describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train["processing_fee"]/df_train["loan_amount"])>0.03][["processing_fee", "loan_amount"]]
# Out:
#        processing_fee  loan_amount
# 23981      2669791.02      2234000
# 28174      1214492.67       966000
# 47089      1858964.77      1738000
# 29305      3036378.01      2616000
# 9898       5293543.52      3626000

# %%
df_train_1 = df_train[(df_train["processing_fee"]/df_train["loan_amount"])<0.03].copy()
df_train_1.shape
# Out:
# (37488, 33)

# %%
df_test["residence_type"].isna().sum()
# Out:
# np.int64(0)

# %%
# Apply same step on test set
df_test = df_test[(df_test["processing_fee"]/df_test["loan_amount"])<0.03].copy()
df_test.shape
# Out:
# (12497, 33)

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train_1[df_train_1["gst"]/df_train_1["loan_amount"]>0.2].shape
# Out:
# (0, 33)

# %%
# Rule 2: Net disbursement should not be higher than loan_amount
df_train_1[df_train_1["net_disbursement"]>df_train_1["loan_amount"]].shape
# Out:
# (0, 33)

# %% [markdown]
# No rows found that breaks rule 1 and rule 2

# %% [markdown]
# ### Analyze Categorical Columns

# %%
cols_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
for col in cols_categorical:
    print(col, "-->",df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %% [markdown]
# ### Fix Errors in Loan Purpose Column

# %%
df_train_1["loan_purpose"] = df_train_1["loan_purpose"].replace("Personaal", "Personal")
df_train_1["loan_purpose"].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
# same for test column
df_test["loan_purpose"] = df_test["loan_purpose"].replace("Personaal", "Personal")
df_test["loan_purpose"].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %% [markdown]
# <h3 align="center" style="color:yellow">Exploratory Data Analysis</h3>

# %%
cols_numerical
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %%
df_train_1.groupby("default")["age"].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34265.00 39.77 9.88 18.00 33.00 40.00 46.00 70.00
# 1        3223.00 37.12 9.29 18.00 31.00 37.00 44.00 70.00

# %% [markdown]
# **Insights**
#
# 1. Average age in the default group is little less (37.12) than the average (39.7) of the group that did not default
# 1. Variability (standard deviation) is mostly similar in both the groups
# 1. Both the groups have similar min and max ages

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(df_train_1["age"][df_train_1["default"] == 0], fill=True, label="default 0")
sns.kdeplot(df_train_1["age"][df_train_1["default"] == 1], fill=True, label="default 1")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Orange (defaulted) group is slightly shifted to left indicating that younger folks are more likely to default on their loans

# %% [markdown]
# ### KDE for all columns

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(cols_numerical):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.legend()
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
# 1. In remaining columns the distributions do not give any obvious insights
# 1. Why loan_amount and income did not give any signs of being strong predictors? May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Here are the ideas for feature engineering
#
# a. Loan to Income ratio is a better metric compared to loan amount and income as individual features
#
# b. Delinquent months to loan months ratio is a better metric compared to those two individual
# features
#
# c. Average DPD per delinquent month is a better metric compared to total dpd and total delinquent
# months

# %%
df_train_1["loan_to_income_ratio"] = round(df_train_1["loan_amount"]/df_train_1["income"],2)

# %%
df_test["loan_to_income_ratio"] = round(df_test["loan_amount"]/df_test["income"], 2)

# %%
sns.kdeplot(df_train_1["loan_to_income_ratio"][df_train_1['default']==0], fill=True, label='default=0')
sns.kdeplot(df_train_1["loan_to_income_ratio"][df_train_1['default']==1], fill=True, label='default=1')
plt.legend()
plt.title("loan to income ratio")        
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when LTI is higher indicating that higher LTI means high risk loan

# %%
df_train_1["delinquency_ratio"] = round((df_train_1["delinquent_months"]*100/df_train_1["total_loan_months"]), 2)

# %%
df_test["delinquency_ratio"] = round((df_test["delinquent_months"]*100/df_test["total_loan_months"]),2)

# %%
df_train_1[["delinquent_months", "total_loan_months", "delinquency_ratio"]].head()
# Out:
#        delinquent_months  total_loan_months  delinquency_ratio
# 12746                 20                152              13.16
# 32495                 10                160               6.25
# 43675                 12                 54              22.22
# 9040                   0                 76               0.00
# 13077                  0                 60               0.00

# %%
sns.kdeplot(df_train_1["delinquency_ratio"][df_train_1['default']==0], fill=True, label='default=0')
sns.kdeplot(df_train_1["delinquency_ratio"][df_train_1['default']==1], fill=True, label='default=1')
plt.legend()
plt.title("delinquency_ratio")        
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of delinquency_ratio
# 2. Orange graph has many values when delinquency ratio is higher indicating some correlation on default

# %%
df_train_1["avg_dpd_per_delinquency"] = np.where(
    df_train_1["delinquent_months"] != 0,
    round((df_train_1["total_dpd"] / df_train_1["delinquent_months"]),2),
    0
)

# %%
df_train_1 ["avg_dpd_per_delinquency"].isna().sum()
# Out:
# np.int64(0)

# %%
df_test["avg_dpd_per_delinquency"] = np.where(
    df_test["delinquent_months"] != 0,
    round((df_test["total_dpd"] / df_test["delinquent_months"]), 2),
    0
)

# %%
df_train_1[[ "total_dpd", "delinquent_months", "avg_dpd_per_delinquency"]].head()
# Out:
#        total_dpd  delinquent_months  avg_dpd_per_delinquency
# 12746        118                 20                     5.90
# 32495         62                 10                     6.20
# 43675         67                 12                     5.58
# 9040           0                  0                     0.00
# 13077          0                  0                     0.00

# %%
sns.kdeplot(df_train_1["avg_dpd_per_delinquency"][df_train_1['default']==0], fill=True, label='default=0')
sns.kdeplot(df_train_1["avg_dpd_per_delinquency"][df_train_1['default']==1], fill=True, label='default=1')
plt.legend()
plt.title("avg_dpd_per_delinquency")        
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Graph clearly shows more occurances of default cases when avg_dpd_per_delinquency is high. This means this column is a strong predictor

# %% [markdown]
# ### Feature Selection
#
# Remove columns that are just unique ids and don't have influence on target

# %%
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income_ratio', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
# droping based on technical knowledge
df_train_2 = df_train_1.drop(["cust_id", "loan_id"], axis=1)
df_test = df_test.drop(["cust_id", "loan_id"], axis=1)

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis=1)
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis=1)

# %%
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income_ratio',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  int64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  int64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  int64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  int64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  sanction_amount              37488 non-null  int64
#  13  processing_fee               37488 non-null  float64
#  14  gst                          37488 non-null  int64
#  15  net_disbursement             37488 non-null  int64
#  16  loan_tenure_months           37488 non-null  int64
#  17  principal_outstanding        37488 non-null  int64
#  18  bank_balance_at_application  37488 non-null  int64
#  19  number_of_open_accounts      37488 non-null  int64
#  20  number_of_closed_accounts    37488 non-null  int64
#  21  enquiry_count                37488 non-null  int64
#  22  credit_utilization_ratio     37488 non-null  int64
#  23  default                      37488 non-null  int64
#  24  loan_to_income_ratio         37488 non-null  float64
#  25  delinquency_ratio            37488 non-null  float64
#  26  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(4), int64(15), object(8)
# memory usage: 8.0+ MB

# %%
df_train_3.drop("zipcode", axis=1).select_dtypes(["int64", "float64"]).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income_ratio',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %% [markdown]
# ### VIF to measure multicolinearity

# %%
# first scale the features
from sklearn.preprocessing import MinMaxScaler

X_train = df_train_3.drop("default", axis=1)
y_train = df_train_3["default"]

scaler = MinMaxScaler()

cols_to_scale = X_train.drop("zipcode", axis=1).select_dtypes(["int64", "float64"]).columns

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])

X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address   zipcode  \
# count 37488.00              37488.00                  37488.00  37488.00
# mean      0.41                  0.39                      0.50 418876.24
# std       0.19                  0.31                      0.30 169029.87
# min       0.00                  0.00                      0.00 110001.00
# 25%       0.29                  0.00                      0.23 302001.00
# 50%       0.40                  0.40                      0.50 400001.00
# 75%       0.54                  0.60                      0.77 560001.00
# max       1.00                  1.00                      1.00 700001.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37488.00               37488.00                     37488.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37488.00                   37488.00       37488.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income_ratio  delinquency_ratio  \
# count                  37488.00              37488.00           37488.00
# mean                       0.44                  0.29               0.10
# std                        0.30                  0.23               0.17
# min                        0.00                  0.00               0.00
# 25%                        0.18                  0.11               0.00
# 50%                        0.39                  0.20               0.04
# 75%                        0.68                  0.51               0.13
# max                        1.00                  1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 37488.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.57
# max                       1.00

# %% [markdown]
# Same Transformation on Test set

# %%
X_test = df_test.drop("default", axis=1)
y_test = df_test["default"]

X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])

X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address   zipcode  \
# count 12497.00              12497.00                  12497.00  12497.00
# mean      0.42                  0.38                      0.50 419759.82
# std       0.19                  0.31                      0.30 168845.35
# min       0.00                  0.00                      0.00 110001.00
# 25%       0.29                  0.00                      0.23 302001.00
# 50%       0.42                  0.40                      0.50 411001.00
# 75%       0.54                  0.60                      0.77 560001.00
# max       1.00                  1.00                      1.00 700001.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min              -0.00           -0.00    -0.00             -0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.09     0.09              0.09
# max               0.98            0.96     0.96              0.96
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12497.00               12497.00                     12497.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.25                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.20                         0.08
# 75%                  0.55                   0.36                         0.16
# max                  1.00                   1.00                         0.94
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12497.00                   12497.00       12497.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income_ratio  delinquency_ratio  \
# count                  12497.00              12497.00           12497.00
# mean                       0.44                  0.29               0.11
# std                        0.30                  0.23               0.17
# min                        0.00                  0.00               0.00
# 25%                        0.18                  0.11               0.00
# 50%                        0.39                  0.20               0.04
# 75%                        0.68                  0.50               0.13
# max                        1.00                  1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12497.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.44
# 75%                       0.58
# max                       1.00

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df["column"] = data.columns
    vif_df["VIF"] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
    return vif_df

# %%
X_train.head(2)
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
#
#        zipcode  ... loan_tenure_months principal_outstanding  \
# 12746   500001  ...               0.42                  1.00
# 32495   400001  ...               0.83                  0.09
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
#
#        loan_to_income_ratio  delinquency_ratio  avg_dpd_per_delinquency
# 12746                  0.41               0.13                     0.59
# 32495                  0.31               0.06                     0.62
#
# [2 rows x 26 columns]

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
#                          column    VIF
# 0                           age   5.55
# 1          number_of_dependants   2.72
# 2      years_at_current_address   3.36
# 3               sanction_amount 101.08
# 4                processing_fee    inf
# 5                           gst    inf
# 6              net_disbursement    inf
# 7            loan_tenure_months   6.17
# 8         principal_outstanding  16.32
# 9   bank_balance_at_application   9.33
# 10      number_of_open_accounts   4.38
# 11    number_of_closed_accounts   2.36
# 12                enquiry_count   6.33
# 13     credit_utilization_ratio   2.90
# 14         loan_to_income_ratio   6.89
# 15            delinquency_ratio   1.93
# 16      avg_dpd_per_delinquency   2.90

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']

X_train_1 = X_train.drop(features_to_drop_vif, axis=1)

numeric_columns = X_train_1.drop("zipcode", axis=1).select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income_ratio', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
calculate_vif(X_train_1[numeric_columns])
# Out:
#                          column  VIF
# 0                           age 5.27
# 1          number_of_dependants 2.72
# 2      years_at_current_address 3.34
# 3            loan_tenure_months 6.01
# 4   bank_balance_at_application 1.80
# 5       number_of_open_accounts 4.35
# 6     number_of_closed_accounts 2.35
# 7                 enquiry_count 6.30
# 8      credit_utilization_ratio 2.88
# 9          loan_to_income_ratio 4.54
# 10            delinquency_ratio 1.93
# 11      avg_dpd_per_delinquency 2.90

# %%
vif_df = calculate_vif(X_train_1[numeric_columns])
# 
selected_numeric_features_vif = vif_df.columns.values
selected_numeric_features_vif
# Out:
# array(['column', 'VIF'], dtype=object)

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Selection: Categorical Featues

# %%
X_train_1.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
# 43675 0.38      M         Single          Salaried                  0.00
# 9040  0.46      M        Married          Salaried                  0.40
# 13077 0.77      M        Married     Self-Employed                  0.80
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
# 43675       Mortgage                      0.83    Chennai   Tamil Nadu
# 9040        Mortgage                      0.97  Bangalore    Karnataka
# 13077          Owned                      0.93       Pune  Maharashtra
#
#        zipcode  ...  loan_type loan_tenure_months  \
# 12746   500001  ...    Secured               0.42
# 32495   400001  ...    Secured               0.83
# 43675   600001  ...    Secured               0.49
# 9040    560001  ...    Secured               0.64
# 13077   411001  ...  Unsecured               0.17
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
# 43675                         0.17                     0.00
# 9040                          0.08                     0.67
# 13077                         0.07                     0.00
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
# 43675                       0.50           0.38                      0.00
# 9040                        0.00           0.88                      0.88
# 13077                       1.00           0.00                      0.72
#
#        loan_to_income_ratio  delinquency_ratio  avg_dpd_per_delinquency
# 12746                  0.41               0.13                     0.59
# 32495                  0.31               0.06                     0.62
# 43675                  0.76               0.22                     0.56
# 9040                   0.19               0.00                     0.00
# 13077                  0.05               0.00                     0.00
#
# [5 rows x 21 columns]

# %%
cols_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %% [markdown]
# ### Calulate the WoE and IV

# %% [markdown]
# X_train

# %%
v = X_train_1.groupby("loan_purpose")["age"].agg(['count','sum'])
v = v.rename(columns={"count": "Total", "sum": "Default"})
v["Default_0"] = v["Total"] - v["Default"]
v.head()
# Out:
#               Total  Default  Default_0
# loan_purpose
# Auto           7447  3097.48    4349.52
# Education      5620  2303.85    3316.15
# Home          11304  4675.33    6628.67
# Personal      13117  5452.37    7664.63

# %%
df.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'default',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'total_loan_months', 'delinquent_months', 'total_dpd', 'enquiry_count',
#        'credit_utilization_ratio'],
#       dtype='object')

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(["count", "sum"])
    grouped = grouped.rename(columns=({"count": "Total", "sum": "Good"}))
    grouped["Bad"] = grouped["Total"] - grouped["Good"]

    total_good = grouped["Good"].sum()
    total_bad = grouped["Bad"].sum()

    grouped["Good_pct"] = grouped["Good"]/total_good
    grouped["Bad_pct"] = grouped["Bad"]/total_bad

    # calculate WoE and IV
    grouped["WoE"] = np.log(grouped["Good_pct"]/grouped["Bad_pct"])
    grouped["IV"] = grouped["WoE"]*(grouped["Good_pct"]-grouped["Bad_pct"])

    grouped['woe'] = grouped['WoE'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['IV'].replace([np.inf, -np.inf], 0)

    total_IV = grouped["IV"].sum()

    return grouped, total_IV

# %%
grouped, total_IV = calculate_woe_iv(pd.concat([X_train_1, y_train], axis=1), "loan_purpose", "default")
grouped
# Out:
#               Total  Good    Bad  Good_pct  Bad_pct   WoE   IV   woe   iv
# loan_purpose
# Auto           7447   327   7120      0.10     0.21 -0.72 0.08 -0.72 0.08
# Education      5620   559   5061      0.17     0.15  0.16 0.00  0.16 0.00
# Home          11304  1734   9570      0.54     0.28  0.66 0.17  0.66 0.17
# Personal      13117   603  12514      0.19     0.37 -0.67 0.12 -0.67 0.12

# %%
total_IV
# Out:
# np.float64(0.3691197842282755)

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  float64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  float64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  float64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  int64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  loan_tenure_months           37488 non-null  float64
#  13  bank_balance_at_application  37488 non-null  float64
#  14  number_of_open_accounts      37488 non-null  float64
#  15  number_of_closed_accounts    37488 non-null  float64
#  16  enquiry_count                37488 non-null  float64
#  17  credit_utilization_ratio     37488 non-null  float64
#  18  loan_to_income_ratio         37488 non-null  float64
#  19  delinquency_ratio            37488 non-null  float64
#  20  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 6.3+ MB

# %%
iv_values = {}


for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
        
iv_values
# Out:
# {'age': np.float64(0.0890689462679479),
#  'gender': np.float64(0.00047449502170914947),
#  'marital_status': np.float64(0.001129766845390142),
#  'employment_status': np.float64(0.003953046301722585),
#  'number_of_dependants': np.float64(0.0019380899135053508),
#  'residence_type': np.float64(0.246745268718145),
#  'years_at_current_address': np.float64(0.0020800513608156363),
#  'city': np.float64(0.0019059578709781529),
#  'state': np.float64(0.0019005589806779287),
#  'zipcode': np.float64(0.0016677413243392572),
#  'loan_purpose': np.float64(0.3691197842282755),
#  'loan_type': np.float64(0.16319324904149224),
#  'loan_tenure_months': np.float64(0.21893515090196278),
#  'bank_balance_at_application': np.float64(0.0063187993277516365),
#  'number_of_open_accounts': np.float64(0.08463134083005877),
#  'number_of_closed_accounts': np.float64(0.0011964272592421567),
#  'enquiry_count': np.float64(0.007864214085342608),
#  'credit_utilization_ratio': np.float64(2.352965568168245),
#  'loan_to_income_ratio': np.float64(0.476415456948364),
#  'delinquency_ratio': np.float64(0.716576108689321),
#  'avg_dpd_per_delinquency': np.float64(0.40176623566177694)}

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

iv_df = pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df = iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.353
# 19            delinquency_ratio 0.717
# 18         loan_to_income_ratio 0.476
# 20      avg_dpd_per_delinquency 0.402
# 10                 loan_purpose 0.369
# 5                residence_type 0.247
# 12           loan_tenure_months 0.219
# 11                    loan_type 0.163
# 0                           age 0.089
# 14      number_of_open_accounts 0.085
# 16                enquiry_count 0.008
# 13  bank_balance_at_application 0.006
# 3             employment_status 0.004
# 6      years_at_current_address 0.002
# 4          number_of_dependants 0.002
# 7                          city 0.002
# 8                         state 0.002
# 9                       zipcode 0.002
# 15    number_of_closed_accounts 0.001
# 2                marital_status 0.001
# 1                        gender 0.000

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income_ratio',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# ### Feature Encoding

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
#
#        credit_utilization_ratio  loan_to_income_ratio  delinquency_ratio  \
# 12746                     0.364                 0.415              0.132
# 32495                     0.051                 0.307              0.062
# 43675                     0.000                 0.759              0.222
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                  True                  False
# 32495                    0.620                  True                  False
# 43675                    0.558                 False                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                   False               True                  False
# 32495                    True              False                  False
# 43675                   False               True                  False
#
#        loan_type_Unsecured
# 12746                False
# 32495                False
# 43675                False

# %%
X_train_encoded.shape
# Out:
# (37488, 13)

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
#
#        credit_utilization_ratio  loan_to_income_ratio  delinquency_ratio  \
# 19205                     0.990                 0.550              0.000
# 15514                     0.323                 0.220              0.000
# 30367                     0.828                 0.180              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
# 30367                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
# 30367                   False              False                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False
# 30367                False

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Attempt 1
#
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
X_test_encoded.head()
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
# 35347 0.365               0.755                    1.000
# 41814 0.577               0.717                    0.667
#
#        credit_utilization_ratio  loan_to_income_ratio  delinquency_ratio  \
# 19205                     0.990                 0.550              0.000
# 15514                     0.323                 0.220              0.000
# 30367                     0.828                 0.180              0.000
# 35347                     0.485                 0.571              0.024
# 41814                     0.980                 0.407              0.107
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
# 30367                    0.000                  True                  False
# 35347                    0.700                  True                  False
# 41814                    0.636                 False                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
# 30367                   False              False                  False
# 35347                   False               True                  False
# 41814                   False               True                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False
# 30367                False
# 35347                False
# 41814                False

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# For us Recall is most important than Precision, Recall shold be above 90%

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.70      0.77      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.76      0.79      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.87      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# Since there is not much difference between XGB and Logistic, we will choose
# LogisticRegression as a candidate for our RandomizedSearchCV candidate it has a
# better interpretation.

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    "C": np.logspace(-4,4,20),
    "solver": ["lbfgs", "saga", "liblinear", "newton-cg"]
}

log_reg = LogisticRegression(max_iter=10000)

random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,
    cv=3,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_train_encoded, y_train)

print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters: {'solver': 'lbfgs', 'C': np.float64(1.623776739188721)}
# Best Score: 0.9609741784037559
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.84      0.73      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.8, 'scale_pos_weight': 2, 'reg_lambda': 1.0, 'reg_alpha': 5.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Best Score: 0.7890826398743216
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.76      0.84      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.87      0.91      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# ### Attempt 2
#
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)

X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# default
# 0    3223
# 1    3223
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.95      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.99      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.95      0.81     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek (OverSampling)
# 1. Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek 

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# default
# 0    34199
# 1    34199
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# %%
# Define the objective function for Optuna
def objective(trial):
    param={
        'C': trial.suggest_float('C', 1e-4, 1e4, log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])  # Class weights
    }
    
    model = LogisticRegression(**param, max_iter=10000)

     # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
 
    return np.mean(scores)

study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2026-03-22 20:25:33,712] A new study created in memory with name: no-name-1dd7fe70-0234-4ced-80c1-b8fab8e72ae7
# [I 2026-03-22 20:25:34,340] Trial 0 finished with value: 0.9088276284545266 and parameters: {'C': 0.004464670241450005, 'solver': 'liblinear', 'tol': 0.0001791703434871034, 'class_weight': None}. Best is trial 0 with value: 0.9088276284545266.
# [I 2026-03-22 20:25:35,007] Trial 1 finished with value: 0.9459038364704654 and parameters: {'C': 3.8316511265491253, 'solver': 'lbfgs', 'tol': 5.11048478189932e-06, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:35,438] Trial 2 finished with value: 0.9438240869427682 and parameters: {'C': 38.70397137543814, 'solver': 'liblinear', 'tol': 0.08997169297422566, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:35,817] Trial 3 finished with value: 0.8522687314178357 and parameters: {'C': 0.0002445671283318913, 'solver': 'saga', 'tol': 0.04217947646545261, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:36,359] Trial 4 finished with value: 0.9458140641419656 and parameters: {'C': 1.405472183953515, 'solver': 'newton-cg', 'tol': 1.5126266839614566e-05, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:36,732] Trial 5 finished with value: 0.8173810660009667 and parameters: {'C': 0.00010220159706214344, 'solver': 'newton-cg', 'tol': 5.486962518636696e-06, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:37,051] Trial 6 finished with value: 0.9297080974831416 and parameters: {'C': 697.9476217239047, 'solver': 'newton-cg', 'tol': 0.015245084879516566, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:37,617] Trial 7 finished with value: 0.9456710940877812 and parameters: {'C': 124.8463913109257, 'solver': 'saga', 'tol': 0.00010212553951378609, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:37,823] Trial 8 finished with value: 0.8276817451891109 and parameters: {'C': 0.0002943907721989383, 'solver': 'liblinear', 'tol': 0.00593740642214145, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:38,635] Trial 9 finished with value: 0.9125491651040006 and parameters: {'C': 0.0016608420386202813, 'solver': 'saga', 'tol': 1.4196044228000003e-06, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:38,979] Trial 10 finished with value: 0.9452604679168455 and parameters: {'C': 8621.264069938117, 'solver': 'lbfgs', 'tol': 0.0013557502845671008, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:39,349] Trial 11 finished with value: 0.9429806208996725 and parameters: {'C': 0.19345463844810212, 'solver': 'lbfgs', 'tol': 1.3964109430741465e-05, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:39,827] Trial 12 finished with value: 0.9457257607451574 and parameters: {'C': 1.1361376218344041, 'solver': 'newton-cg', 'tol': 2.4090599257782345e-05, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:40,315] Trial 13 finished with value: 0.9457699796395241 and parameters: {'C': 1.2925339633603703, 'solver': 'lbfgs', 'tol': 1.2550230047845739e-06, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:40,590] Trial 14 finished with value: 0.9408059044889928 and parameters: {'C': 0.08683223203665069, 'solver': 'lbfgs', 'tol': 5.8370398564692004e-05, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:41,106] Trial 15 finished with value: 0.9457434256911714 and parameters: {'C': 7.568725026295697, 'solver': 'newton-cg', 'tol': 8.615070785887898e-06, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:41,544] Trial 16 finished with value: 0.9376306058363596 and parameters: {'C': 0.03946396239887707, 'solver': 'newton-cg', 'tol': 0.0007484777921641997, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:42,064] Trial 17 finished with value: 0.9456856293771047 and parameters: {'C': 60.700802050715694, 'solver': 'lbfgs', 'tol': 4.127608074636269e-06, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:42,626] Trial 18 finished with value: 0.9457872166466829 and parameters: {'C': 6.66666297811616, 'solver': 'newton-cg', 'tol': 4.4312838734475703e-05, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:42,961] Trial 19 finished with value: 0.9331343145443011 and parameters: {'C': 0.01655845480538428, 'solver': 'lbfgs', 'tol': 0.00035046007530149147, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:43,472] Trial 20 finished with value: 0.9446832755402621 and parameters: {'C': 0.3669000072729357, 'solver': 'lbfgs', 'tol': 2.9537521149961554e-06, 'class_weight': None}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:43,973] Trial 21 finished with value: 0.9457726139792678 and parameters: {'C': 7.141332419832015, 'solver': 'newton-cg', 'tol': 3.248837451705861e-05, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:44,528] Trial 22 finished with value: 0.9458602045570959 and parameters: {'C': 4.691729884101588, 'solver': 'newton-cg', 'tol': 4.5241903570531686e-05, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9459038364704654.
# [I 2026-03-22 20:25:45,124] Trial 23 finished with value: 0.945931677039432 and parameters: {'C': 1.8825144373926677, 'solver': 'newton-cg', 'tol': 1.4032172090951592e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:45,679] Trial 24 finished with value: 0.9456856919837988 and parameters: {'C': 761.9281799456049, 'solver': 'newton-cg', 'tol': 0.00010445959855596854, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:46,300] Trial 25 finished with value: 0.945699865071776 and parameters: {'C': 15.53907842447495, 'solver': 'newton-cg', 'tol': 3.0323970450013342e-06, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:46,811] Trial 26 finished with value: 0.9456710940877812 and parameters: {'C': 210.87071089767298, 'solver': 'liblinear', 'tol': 9.084103735497541e-06, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:47,404] Trial 27 finished with value: 0.9449030168760632 and parameters: {'C': 0.41083588182681585, 'solver': 'saga', 'tol': 2.237496732715505e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:47,879] Trial 28 finished with value: 0.9457114344246529 and parameters: {'C': 2.625321944831466, 'solver': 'newton-cg', 'tol': 0.0002932375418724767, 'class_weight': None}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:48,205] Trial 29 finished with value: 0.9242903530683405 and parameters: {'C': 0.013847359649381028, 'solver': 'liblinear', 'tol': 0.00011453523119586071, 'class_weight': None}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:48,439] Trial 30 finished with value: 0.9400664532632864 and parameters: {'C': 25.082797381702168, 'solver': 'lbfgs', 'tol': 0.002370068064542399, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:48,939] Trial 31 finished with value: 0.9458589495176848 and parameters: {'C': 2.3616732661921143, 'solver': 'newton-cg', 'tol': 1.4437250838783034e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:49,467] Trial 32 finished with value: 0.9458894043453121 and parameters: {'C': 4.581006674796906, 'solver': 'newton-cg', 'tol': 7.97328593251992e-06, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:50,007] Trial 33 finished with value: 0.9450644927368734 and parameters: {'C': 0.4664354424674419, 'solver': 'newton-cg', 'tol': 7.369599816436056e-06, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:50,636] Trial 34 finished with value: 0.9458456497259204 and parameters: {'C': 4.681738100773073, 'solver': 'newton-cg', 'tol': 1.9306701739637614e-06, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:51,183] Trial 35 finished with value: 0.9456708285526642 and parameters: {'C': 34.30900705820415, 'solver': 'newton-cg', 'tol': 4.757525550096031e-06, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:51,585] Trial 36 finished with value: 0.9383344774384971 and parameters: {'C': 0.08249093562854784, 'solver': 'liblinear', 'tol': 5.904982371449253e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:52,244] Trial 37 finished with value: 0.9456710940877812 and parameters: {'C': 126.81999304256544, 'solver': 'saga', 'tol': 1.805677735122513e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:52,831] Trial 38 finished with value: 0.945699865071776 and parameters: {'C': 15.84172519935132, 'solver': 'newton-cg', 'tol': 2.1696639013834056e-06, 'class_weight': None}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:53,379] Trial 39 finished with value: 0.9456856919837988 and parameters: {'C': 749.7141181521527, 'solver': 'newton-cg', 'tol': 9.076795415055969e-06, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:53,589] Trial 40 finished with value: 0.944830544838214 and parameters: {'C': 0.6365561248407245, 'solver': 'saga', 'tol': 0.09847969238801423, 'class_weight': None}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:54,096] Trial 41 finished with value: 0.945844167623482 and parameters: {'C': 2.1902082988559184, 'solver': 'newton-cg', 'tol': 1.6699275706680028e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:54,613] Trial 42 finished with value: 0.945918219858342 and parameters: {'C': 3.223185445586161, 'solver': 'newton-cg', 'tol': 1.2502134802563553e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:55,168] Trial 43 finished with value: 0.9431862741122613 and parameters: {'C': 0.21022852569279354, 'solver': 'newton-cg', 'tol': 3.4062590059826344e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.945931677039432.
# [I 2026-03-22 20:25:55,734] Trial 44 finished with value: 0.9459330359676946 and parameters: {'C': 3.600715273467734, 'solver': 'newton-cg', 'tol': 4.875807584918587e-06, 'class_weight': 'balanced'}. Best is trial 44 with value: 0.9459330359676946.
# [I 2026-03-22 20:25:56,241] Trial 45 finished with value: 0.9457257607451574 and parameters: {'C': 1.1293802168460814, 'solver': 'newton-cg', 'tol': 4.9822155834066595e-06, 'class_weight': 'balanced'}. Best is trial 44 with value: 0.9459330359676946.
# [I 2026-03-22 20:25:56,685] Trial 46 finished with value: 0.9456856293771047 and parameters: {'C': 62.768154450097406, 'solver': 'lbfgs', 'tol': 2.290188004411763e-06, 'class_weight': 'balanced'}. Best is trial 44 with value: 0.9459330359676946.
# [I 2026-03-22 20:25:57,233] Trial 47 finished with value: 0.9456999203153748 and parameters: {'C': 18.70193277539579, 'solver': 'newton-cg', 'tol': 6.026375780379077e-06, 'class_weight': None}. Best is trial 44 with value: 0.9459330359676946.
# [I 2026-03-22 20:25:57,562] Trial 48 finished with value: 0.9403859628228117 and parameters: {'C': 0.144646314032333, 'solver': 'liblinear', 'tol': 0.03150283968433017, 'class_weight': 'balanced'}. Best is trial 44 with value: 0.9459330359676946.
# [I 2026-03-22 20:25:58,001] Trial 49 finished with value: 0.9457727011690048 and parameters: {'C': 10.76401613517549, 'solver': 'lbfgs', 'tol': 1.6313263071599645e-06, 'class_weight': 'balanced'}. Best is trial 44 with value: 0.9459330359676946.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)


# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)


report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9459330359676946
#   Params:
#     C: 3.600715273467734
#     solver: newton-cg
#     tol: 4.875807584918587e-06
#     class_weight: balanced
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ### Attempt 4
#
#
# 1. XGBoost
# 1. Handle Class Imbalance Using S
# 1. Parameter tunning using optuna

# %%
# Define the objective function for Optuna

def objective(trial):
    param={
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4,1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param) 

    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
        
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2026-03-22 20:25:58,522] A new study created in memory with name: no-name-d29bdf93-9070-4019-9238-3169053259e2
# [I 2026-03-22 20:26:00,136] Trial 0 finished with value: 0.9683237958449503 and parameters: {'lambda': 0.11487091789380323, 'alpha': 0.005135160299984852, 'subsample': 0.9448809138874598, 'colsample_bytree': 0.41669862942905245, 'max_depth': 10, 'eta': 0.1724770793385385, 'gamma': 2.7548191456605844, 'scale_pos_weight': 5.00064795394681, 'min_child_weight': 9, 'max_delta_step': 2}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:01,311] Trial 1 finished with value: 0.9615759855732003 and parameters: {'lambda': 0.0058310765437255664, 'alpha': 0.08143785238128678, 'subsample': 0.638538760426472, 'colsample_bytree': 0.4046748533025265, 'max_depth': 6, 'eta': 0.14084724048023728, 'gamma': 2.4813385646115247, 'scale_pos_weight': 3.3278125961370626, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:03,085] Trial 2 finished with value: 0.9514998006018095 and parameters: {'lambda': 0.014019189592965397, 'alpha': 0.3597420703536838, 'subsample': 0.9745465538287084, 'colsample_bytree': 0.5902918562116448, 'max_depth': 6, 'eta': 0.08500282160852603, 'gamma': 1.1981393479218871, 'scale_pos_weight': 6.3568377224811154, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:04,086] Trial 3 finished with value: 0.9541080736435851 and parameters: {'lambda': 0.002872911221319116, 'alpha': 0.0010093276910347726, 'subsample': 0.8529526059720604, 'colsample_bytree': 0.9619345548132554, 'max_depth': 3, 'eta': 0.21741081491091052, 'gamma': 4.41227782869671, 'scale_pos_weight': 4.548284003805515, 'min_child_weight': 10, 'max_delta_step': 10}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:05,391] Trial 4 finished with value: 0.9651934226526248 and parameters: {'lambda': 0.0036400336491082593, 'alpha': 0.072353093097643, 'subsample': 0.6247683041664726, 'colsample_bytree': 0.6836323264503519, 'max_depth': 6, 'eta': 0.174522858312143, 'gamma': 9.270910154987313, 'scale_pos_weight': 1.9294127322612888, 'min_child_weight': 6, 'max_delta_step': 0}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:06,638] Trial 5 finished with value: 0.935028640349234 and parameters: {'lambda': 2.4081794685816384, 'alpha': 0.2397800188567788, 'subsample': 0.9568669550243577, 'colsample_bytree': 0.531223127273652, 'max_depth': 3, 'eta': 0.11363828211693204, 'gamma': 3.669812349699252, 'scale_pos_weight': 4.343909885678293, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:08,386] Trial 6 finished with value: 0.9119553159396286 and parameters: {'lambda': 0.4925782757621922, 'alpha': 0.002798041230666881, 'subsample': 0.5976385619358304, 'colsample_bytree': 0.5175525131616636, 'max_depth': 3, 'eta': 0.0618415795650147, 'gamma': 6.516802578455812, 'scale_pos_weight': 3.6424012542301365, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:09,622] Trial 7 finished with value: 0.9523880756972223 and parameters: {'lambda': 1.1644671691939454, 'alpha': 1.8908774535618351, 'subsample': 0.8292234117415007, 'colsample_bytree': 0.5777286334659937, 'max_depth': 3, 'eta': 0.1834430121443603, 'gamma': 8.29245576488193, 'scale_pos_weight': 3.319646903491673, 'min_child_weight': 1, 'max_delta_step': 5}. Best is trial 0 with value: 0.9683237958449503.
# [I 2026-03-22 20:26:11,446] Trial 8 finished with value: 0.9690737856510516 and parameters: {'lambda': 0.0010006135439712077, 'alpha': 0.0565745664749281, 'subsample': 0.7322589328429322, 'colsample_bytree': 0.41991757452749245, 'max_depth': 10, 'eta': 0.2048618460147189, 'gamma': 3.0670712214249973, 'scale_pos_weight': 4.178232601068878, 'min_child_weight': 5, 'max_delta_step': 1}. Best is trial 8 with value: 0.9690737856510516.
# [I 2026-03-22 20:26:12,614] Trial 9 finished with value: 0.9586678896669897 and parameters: {'lambda': 0.004220450979295056, 'alpha': 2.4146702706468663, 'subsample': 0.6672520932828331, 'colsample_bytree': 0.7639660252818495, 'max_depth': 4, 'eta': 0.20716322929084977, 'gamma': 8.898040617356362, 'scale_pos_weight': 4.157599648547818, 'min_child_weight': 1, 'max_delta_step': 7}. Best is trial 8 with value: 0.9690737856510516.
# [I 2026-03-22 20:26:14,927] Trial 10 finished with value: 0.9743756861042593 and parameters: {'lambda': 0.028162653726840573, 'alpha': 0.019833702337352717, 'subsample': 0.4607152871137595, 'colsample_bytree': 0.8569698346841725, 'max_depth': 10, 'eta': 0.289830500047961, 'gamma': 0.03609635094557806, 'scale_pos_weight': 8.86074136950181, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:17,011] Trial 11 finished with value: 0.9741559945407771 and parameters: {'lambda': 0.039870887010836464, 'alpha': 0.020085921777398996, 'subsample': 0.40698424808074407, 'colsample_bytree': 0.8788202731792735, 'max_depth': 10, 'eta': 0.2973076678426707, 'gamma': 0.1335842960458691, 'scale_pos_weight': 9.66599473934303, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:18,664] Trial 12 finished with value: 0.9725455568815832 and parameters: {'lambda': 0.044019393191267256, 'alpha': 0.014683438525182306, 'subsample': 0.40524680584037637, 'colsample_bytree': 0.9084336280820955, 'max_depth': 8, 'eta': 0.28816775164289854, 'gamma': 0.15385644196843878, 'scale_pos_weight': 9.903191568331765, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:20,226] Trial 13 finished with value: 0.9720325813050575 and parameters: {'lambda': 0.1096151580702587, 'alpha': 0.01879092971985251, 'subsample': 0.4120945837194326, 'colsample_bytree': 0.8410035530071809, 'max_depth': 8, 'eta': 0.291924003252479, 'gamma': 0.4813294162127586, 'scale_pos_weight': 9.803144124314025, 'min_child_weight': 4, 'max_delta_step': 6}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:22,965] Trial 14 finished with value: 0.9718993315613019 and parameters: {'lambda': 0.031842981316029674, 'alpha': 0.01535596184586499, 'subsample': 0.5023141670717761, 'colsample_bytree': 0.8278575196236106, 'max_depth': 9, 'eta': 0.251517043211176, 'gamma': 1.6482434908405046, 'scale_pos_weight': 8.0649487298195, 'min_child_weight': 7, 'max_delta_step': 3}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:28,129] Trial 15 finished with value: 0.9480820992139841 and parameters: {'lambda': 0.3004414011897496, 'alpha': 0.4633550174940563, 'subsample': 0.5018868866470927, 'colsample_bytree': 0.9794690478153922, 'max_depth': 8, 'eta': 0.020872726685320142, 'gamma': 1.58239723808004, 'scale_pos_weight': 8.051898690502881, 'min_child_weight': 3, 'max_delta_step': 8}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:31,570] Trial 16 finished with value: 0.9635389902523848 and parameters: {'lambda': 5.980337420648267, 'alpha': 0.006727709716704948, 'subsample': 0.5153893804143989, 'colsample_bytree': 0.7176849199556339, 'max_depth': 9, 'eta': 0.25357705487910903, 'gamma': 5.661292209642776, 'scale_pos_weight': 8.495019089053983, 'min_child_weight': 7, 'max_delta_step': 4}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:36,429] Trial 17 finished with value: 0.968204092019917 and parameters: {'lambda': 0.02081095217575283, 'alpha': 9.071886448829314, 'subsample': 0.46144103587369395, 'colsample_bytree': 0.8804275408675784, 'max_depth': 10, 'eta': 0.2527639728246877, 'gamma': 0.06245940735844431, 'scale_pos_weight': 6.689509824642513, 'min_child_weight': 3, 'max_delta_step': 5}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:39,856] Trial 18 finished with value: 0.968835681660794 and parameters: {'lambda': 0.06623125268325228, 'alpha': 0.0012902080367823534, 'subsample': 0.5675915316881253, 'colsample_bytree': 0.7989496847212947, 'max_depth': 9, 'eta': 0.29862742633760675, 'gamma': 5.162856899897165, 'scale_pos_weight': 8.874319390384061, 'min_child_weight': 6, 'max_delta_step': 3}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:42,903] Trial 19 finished with value: 0.9641422247851166 and parameters: {'lambda': 0.26404154071660296, 'alpha': 0.03310825784329784, 'subsample': 0.7696216103809173, 'colsample_bytree': 0.916975578927814, 'max_depth': 7, 'eta': 0.26406240037776585, 'gamma': 7.631916701414544, 'scale_pos_weight': 7.249087376350054, 'min_child_weight': 4, 'max_delta_step': 2}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:46,322] Trial 20 finished with value: 0.9605005854671974 and parameters: {'lambda': 0.01196779080097205, 'alpha': 0.15842269372153542, 'subsample': 0.4581827983728185, 'colsample_bytree': 0.6739632977416045, 'max_depth': 5, 'eta': 0.2280422185757646, 'gamma': 1.2178819495756943, 'scale_pos_weight': 9.18652837425953, 'min_child_weight': 5, 'max_delta_step': 8}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:50,897] Trial 21 finished with value: 0.9722522138063249 and parameters: {'lambda': 0.03437214599126703, 'alpha': 0.01162326927630774, 'subsample': 0.40684245381779377, 'colsample_bytree': 0.9039519383495127, 'max_depth': 8, 'eta': 0.2794740189905797, 'gamma': 0.008823464826181876, 'scale_pos_weight': 9.976058474126258, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:26:55,509] Trial 22 finished with value: 0.9733952768930593 and parameters: {'lambda': 0.06474694964665964, 'alpha': 0.03254708589408312, 'subsample': 0.4032838605685199, 'colsample_bytree': 0.9947589693795134, 'max_depth': 9, 'eta': 0.2970473448341334, 'gamma': 0.7263165827366104, 'scale_pos_weight': 9.482837735874662, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 10 with value: 0.9743756861042593.
# [I 2026-03-22 20:27:00,408] Trial 23 finished with value: 0.9751369460338868 and parameters: {'lambda': 0.14947735999446207, 'alpha': 0.03358399254440665, 'subsample': 0.5450864431396063, 'colsample_bytree': 0.9969190808531747, 'max_depth': 10, 'eta': 0.23649563132926915, 'gamma': 0.9433266331336851, 'scale_pos_weight': 7.292583713965226, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:05,022] Trial 24 finished with value: 0.9739652084540932 and parameters: {'lambda': 0.1866763289273758, 'alpha': 0.004102049118893975, 'subsample': 0.5458541617041366, 'colsample_bytree': 0.9436738476167689, 'max_depth': 10, 'eta': 0.2342839247893491, 'gamma': 1.778178761487186, 'scale_pos_weight': 7.442887629580301, 'min_child_weight': 2, 'max_delta_step': 6}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:09,428] Trial 25 finished with value: 0.9735258157109111 and parameters: {'lambda': 0.6983564607668592, 'alpha': 0.02910371545833318, 'subsample': 0.46842052353047636, 'colsample_bytree': 0.8754866833382895, 'max_depth': 10, 'eta': 0.2660811768067976, 'gamma': 2.2109997642405532, 'scale_pos_weight': 6.00414354042714, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:11,005] Trial 26 finished with value: 0.970626033640832 and parameters: {'lambda': 0.008830848874238946, 'alpha': 0.009010822552826736, 'subsample': 0.5495151349584857, 'colsample_bytree': 0.7801114087665298, 'max_depth': 9, 'eta': 0.24157726364282722, 'gamma': 3.511577009488084, 'scale_pos_weight': 7.484217553194451, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:12,429] Trial 27 finished with value: 0.9716083868106793 and parameters: {'lambda': 0.020228150537040624, 'alpha': 0.14276799881723293, 'subsample': 0.4574693849092665, 'colsample_bytree': 0.8477107727842554, 'max_depth': 7, 'eta': 0.27502787595609585, 'gamma': 0.8221603304799806, 'scale_pos_weight': 8.551297669321158, 'min_child_weight': 2, 'max_delta_step': 6}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:14,437] Trial 28 finished with value: 0.9699486500451687 and parameters: {'lambda': 0.12586537457740363, 'alpha': 0.002726973472772248, 'subsample': 0.5808725838617236, 'colsample_bytree': 0.7266346227004217, 'max_depth': 10, 'eta': 0.14273872421716088, 'gamma': 2.1694977151920556, 'scale_pos_weight': 5.7082601971362, 'min_child_weight': 7, 'max_delta_step': 1}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:16,023] Trial 29 finished with value: 0.9716065561016394 and parameters: {'lambda': 0.07595166790899303, 'alpha': 0.04798394257932995, 'subsample': 0.5194482793000988, 'colsample_bytree': 0.9417534180867868, 'max_depth': 10, 'eta': 0.20555400671242155, 'gamma': 2.93366783168819, 'scale_pos_weight': 5.2004526015881325, 'min_child_weight': 8, 'max_delta_step': 2}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:17,926] Trial 30 finished with value: 0.9738475308163145 and parameters: {'lambda': 0.001688639961388002, 'alpha': 0.004894133620139561, 'subsample': 0.6817146486130814, 'colsample_bytree': 0.9877931032078194, 'max_depth': 9, 'eta': 0.18523634852911156, 'gamma': 0.7107766848289492, 'scale_pos_weight': 6.881371354251851, 'min_child_weight': 4, 'max_delta_step': 5}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:19,716] Trial 31 finished with value: 0.9736143029656512 and parameters: {'lambda': 0.1656204785070101, 'alpha': 0.0036298718970037567, 'subsample': 0.5592113088845312, 'colsample_bytree': 0.9410639712356168, 'max_depth': 10, 'eta': 0.23084563919624695, 'gamma': 1.7139755644260437, 'scale_pos_weight': 7.777547792064959, 'min_child_weight': 2, 'max_delta_step': 6}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:21,580] Trial 32 finished with value: 0.974742160997441 and parameters: {'lambda': 0.22667387435600028, 'alpha': 0.006491184532878453, 'subsample': 0.625520971074441, 'colsample_bytree': 0.9418230422054352, 'max_depth': 10, 'eta': 0.2718288998764097, 'gamma': 1.0554177806704943, 'scale_pos_weight': 8.936456646675929, 'min_child_weight': 2, 'max_delta_step': 5}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:23,505] Trial 33 finished with value: 0.9739659971705938 and parameters: {'lambda': 0.4555390147797966, 'alpha': 0.024517052734281935, 'subsample': 0.6407601900194514, 'colsample_bytree': 0.8666983170798083, 'max_depth': 9, 'eta': 0.27277171275677375, 'gamma': 1.092216980390163, 'scale_pos_weight': 8.996713960358367, 'min_child_weight': 3, 'max_delta_step': 5}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:25,221] Trial 34 finished with value: 0.972588915477349 and parameters: {'lambda': 0.04185853814881687, 'alpha': 0.009158203503739307, 'subsample': 0.6092237756469293, 'colsample_bytree': 0.804471714977443, 'max_depth': 10, 'eta': 0.28237959630197496, 'gamma': 2.563250208728001, 'scale_pos_weight': 8.688834937909778, 'min_child_weight': 2, 'max_delta_step': 4}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:26,709] Trial 35 finished with value: 0.9702278670188157 and parameters: {'lambda': 1.3225184559312206, 'alpha': 0.001907739041389931, 'subsample': 0.730647682841992, 'colsample_bytree': 0.903879153333161, 'max_depth': 9, 'eta': 0.29946397048261153, 'gamma': 3.940878943326487, 'scale_pos_weight': 9.33993904177417, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:28,886] Trial 36 finished with value: 0.9738783045352165 and parameters: {'lambda': 0.0076707399838570455, 'alpha': 0.11019952985163296, 'subsample': 0.4430432352354888, 'colsample_bytree': 0.9528286043667619, 'max_depth': 10, 'eta': 0.26076270128164436, 'gamma': 1.2497226765258107, 'scale_pos_weight': 8.219324478580583, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:30,589] Trial 37 finished with value: 0.964623585347339 and parameters: {'lambda': 0.020736595398704684, 'alpha': 0.05776667191332625, 'subsample': 0.4944952522906136, 'colsample_bytree': 0.9682330197309033, 'max_depth': 7, 'eta': 0.11845956797491854, 'gamma': 0.5245783859522254, 'scale_pos_weight': 9.325306179811463, 'min_child_weight': 6, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:32,011] Trial 38 finished with value: 0.9738245829828379 and parameters: {'lambda': 0.09668669539523467, 'alpha': 0.008592875458177694, 'subsample': 0.8980018584551508, 'colsample_bytree': 0.9992660996453596, 'max_depth': 8, 'eta': 0.15660501601759202, 'gamma': 2.1435937561774816, 'scale_pos_weight': 1.0449994361470054, 'min_child_weight': 4, 'max_delta_step': 7}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:33,323] Trial 39 finished with value: 0.9658902958360714 and parameters: {'lambda': 0.21688299196639976, 'alpha': 0.017061812876098866, 'subsample': 0.648811057103247, 'colsample_bytree': 0.9260928160439811, 'max_depth': 5, 'eta': 0.23933931065882696, 'gamma': 4.3936835617601435, 'scale_pos_weight': 6.271303091474842, 'min_child_weight': 1, 'max_delta_step': 5}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:35,071] Trial 40 finished with value: 0.9729687768208407 and parameters: {'lambda': 1.0407632693190834, 'alpha': 0.08397944434892082, 'subsample': 0.6004305073620054, 'colsample_bytree': 0.7597438219899123, 'max_depth': 10, 'eta': 0.27742164365971245, 'gamma': 0.004942748942540317, 'scale_pos_weight': 7.100200649987727, 'min_child_weight': 10, 'max_delta_step': 0}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:36,809] Trial 41 finished with value: 0.9740240468287413 and parameters: {'lambda': 0.4242687078673673, 'alpha': 0.022708007165619, 'subsample': 0.6334400041183728, 'colsample_bytree': 0.8733597405313553, 'max_depth': 9, 'eta': 0.2706261362621196, 'gamma': 1.1036780929509813, 'scale_pos_weight': 8.791551159721907, 'min_child_weight': 3, 'max_delta_step': 5}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:37,976] Trial 42 finished with value: 0.9640384987649733 and parameters: {'lambda': 0.4267575539778962, 'alpha': 0.040334748654994194, 'subsample': 0.7263115529225236, 'colsample_bytree': 0.8743224376715206, 'max_depth': 10, 'eta': 0.2216571281696638, 'gamma': 9.889610065507602, 'scale_pos_weight': 8.283659689089976, 'min_child_weight': 2, 'max_delta_step': 4}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:39,719] Trial 43 finished with value: 0.9737310660484776 and parameters: {'lambda': 0.6349353166252218, 'alpha': 0.023801789877188936, 'subsample': 0.5333967720228837, 'colsample_bytree': 0.8229567624415025, 'max_depth': 9, 'eta': 0.2474739453956848, 'gamma': 1.2547274864652707, 'scale_pos_weight': 9.595495239627512, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:41,561] Trial 44 finished with value: 0.9739367005272515 and parameters: {'lambda': 1.7232715316626421, 'alpha': 0.006228574730099199, 'subsample': 0.628818615831123, 'colsample_bytree': 0.6682321215128926, 'max_depth': 10, 'eta': 0.2846092174068904, 'gamma': 0.4286880952945572, 'scale_pos_weight': 7.759446253121333, 'min_child_weight': 4, 'max_delta_step': 5}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:43,151] Trial 45 finished with value: 0.9718982630277077 and parameters: {'lambda': 3.3076427691423005, 'alpha': 0.36343602960810756, 'subsample': 0.43032551384010453, 'colsample_bytree': 0.8928170342409074, 'max_depth': 9, 'eta': 0.2651086678370476, 'gamma': 0.8231800457812863, 'scale_pos_weight': 8.905166756824526, 'min_child_weight': 5, 'max_delta_step': 7}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:44,350] Trial 46 finished with value: 0.9658303613404069 and parameters: {'lambda': 0.36818468541759647, 'alpha': 0.012585278600514328, 'subsample': 0.6998241373335476, 'colsample_bytree': 0.6436645823243817, 'max_depth': 10, 'eta': 0.2813762017662209, 'gamma': 7.038658415329211, 'scale_pos_weight': 8.664643317714823, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:46,378] Trial 47 finished with value: 0.9717681554686957 and parameters: {'lambda': 0.1596245923648934, 'alpha': 0.7531818213573892, 'subsample': 0.48264473355336224, 'colsample_bytree': 0.8506619165249161, 'max_depth': 8, 'eta': 0.21402953820211648, 'gamma': 1.805433203061714, 'scale_pos_weight': 7.9741303710379166, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:47,667] Trial 48 finished with value: 0.9714592778524079 and parameters: {'lambda': 0.0490238690085753, 'alpha': 0.06319677658839243, 'subsample': 0.7690859749530344, 'colsample_bytree': 0.9653493698316129, 'max_depth': 9, 'eta': 0.25810730567146895, 'gamma': 3.047229174613511, 'scale_pos_weight': 9.996238929219992, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 23 with value: 0.9751369460338868.
# [I 2026-03-22 20:27:49,735] Trial 49 finished with value: 0.9699811970594698 and parameters: {'lambda': 0.027647156175842194, 'alpha': 0.02049094089118845, 'subsample': 0.5868230051710271, 'colsample_bytree': 0.43607508715174254, 'max_depth': 10, 'eta': 0.18627649110544098, 'gamma': 0.41947118932211724, 'scale_pos_weight': 9.098478607989739, 'min_child_weight': 2, 'max_delta_step': 6}. Best is trial 23 with value: 0.9751369460338868.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)


# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)


report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9751369460338868
#   Params:
#     lambda: 0.14947735999446207
#     alpha: 0.03358399254440665
#     subsample: 0.5450864431396063
#     colsample_bytree: 0.9969190808531747
#     max_depth: 10
#     eta: 0.23649563132926915
#     gamma: 0.9433266331336851
#     scale_pos_weight: 7.292583713965226
#     min_child_weight: 3
#     max_delta_step: 4
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97     11423
#            1       0.67      0.88      0.76      1074
#
#     accuracy                           0.95     12497
#    macro avg       0.83      0.92      0.87     12497
# weighted avg       0.96      0.95      0.96     12497

# %% [markdown]
# ## Model Evaluation : ROC/AUC

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 8.75426771e-05,
#         8.75426771e-05]),
#  array([0.        , 0.0009311 , 0.16108007, 0.16108007, 0.17690875]),
#  array([       inf, 1.        , 0.99945281, 0.99944718, 0.99932357]))

# %%
from sklearn.metrics import auc


area = auc(fpr, tpr)
area
# Out:
# 0.9836668513703037

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Model Evaluation : Rankordering, KS statistic, Gini coeff

# %%
probabalities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    "Default Truth": y_test,
    "Default Probability": probabilities
})

df_eval.head()
# Out:
#        Default Truth  Default Probability
# 19205              0                0.532
# 15514              0                0.000
# 30367              0                0.006
# 35347              0                0.007
# 41814              1                0.921

# %%
df_eval["Decile"] = pd.qcut(df_eval["Default Probability"], 10, labels=False, duplicates="drop")
df_eval.head()
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.532       8
# 15514              0                0.000       2
# 30367              0                0.006       6
# 35347              0                0.007       6
# 41814              1                0.921       9

# %%
df_eval[df_eval.Decile==8]["Default Probability"].describe()
# Out:
# count   1250.000
# mean       0.485
# std        0.182
# min        0.213
# 25%        0.316
# 50%        0.466
# 75%        0.640
# max        0.818
# Name: Default Probability, dtype: float64

# %%
df_decile = df_eval.groupby("Decile").apply(lambda x:  pd.Series({
    "Minimum Probability": x["Default Probability"].min(),
    "Maximum Probability": x["Default Probability"].max(),
    "Events": x["Default Truth"].sum(),
    "Non Events": x["Default Probability"].count() - x["Default Truth"].sum()
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non Events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.213  10.000    1239.000
# 8       8                0.213                0.818 161.000    1089.000
# 9       9                0.819                1.000 898.000     352.000

# %%
df_decile['Event Rate'] = df_decile['Events']*100 / (df_decile['Events']+df_decile['Non Events'])
df_decile['Non-event Rate'] = df_decile['Non Events']*100 / (df_decile['Events']+df_decile['Non Events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non Events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.213  10.000    1239.000
# 8       8                0.213                0.818 161.000    1089.000
# 9       9                0.819                1.000 898.000     352.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.400          99.600
# 7       0.801          99.199
# 8      12.880          87.120
# 9      71.840          28.160

# %%
df_decile = df_decile.sort_values(by='Decile', ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non Events  \
# 0       9                0.819                1.000 898.000     352.000
# 1       8                0.213                0.818 161.000    1089.000
# 2       7                0.029                0.213  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      71.840          28.160
# 1      12.880          87.120
# 2       0.801          99.199
# 3       0.400          99.600
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile["Cum Events"] = df_decile["Events"].cumsum()
df_decile['Cum Non-Events'] =  df_decile['Non Events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non Events  \
# 0       9                0.819                1.000 898.000     352.000
# 1       8                0.213                0.818 161.000    1089.000
# 2       7                0.029                0.213  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-Events
# 0      71.840          28.160     898.000         352.000
# 1      12.880          87.120    1059.000        1441.000
# 2       0.801          99.199    1069.000        2680.000
# 3       0.400          99.600    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate'] = df_decile['Cum Events'] * 100 / df_decile['Events'].sum()
df_decile['Cum Non-event Rate'] = df_decile['Cum Non-Events']*100 / df_decile['Non Events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non Events  \
# 0       9                0.819                1.000 898.000     352.000
# 1       8                0.213                0.818 161.000    1089.000
# 2       7                0.029                0.213  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-Events  Cum Event Rate  \
# 0      71.840          28.160     898.000         352.000          83.613
# 1      12.880          87.120    1059.000        1441.000          98.603
# 2       0.801          99.199    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.082
# 1              12.615
# 2              23.461
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS'] = abs(df_decile['Cum Event Rate'] - df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non Events  \
# 0       9                0.819                1.000 898.000     352.000
# 1       8                0.213                0.818 161.000    1089.000
# 2       7                0.029                0.213  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-Events  Cum Event Rate  \
# 0      71.840          28.160     898.000         352.000          83.613
# 1      12.880          87.120    1059.000        1441.000          98.603
# 2       0.801          99.199    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.082 80.531
# 1              12.615 85.988
# 2              23.461 76.073
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %% [markdown]
# To assess whether rank ordering is followed, we should look at whether higher deciles (those with higher predicted probabilities) have higher event rates compared to lower deciles. Rank ordering means that as you move from the top decile to the bottom decile, the event rate should generally decrease.
#
# Non-Events - termed as good (customers) who do not default. Events - termed as bad (customers) who default.
#
# Events and Non-Events terms are interchanged based on usecase to usecase.
#
# eg: for marketing usecase, which customer to reach out (who will take loan based on offers) will be events - here it will termed as good, and the customers who will not take loans will be non-events (bad).
#
# **Insights from the Decile Table**
#
# 1. Top Deciles
#
# * The first decile (Decile 9) has a high event rate of 72.00% and a non-event rate of 28.00%. This indicates that the model is highly confident in predicting events in this decile.
# * The second decile (Decile 8) also shows a significant event rate of 12.72%, with a cumulative event rate reaching 98.6%.
#
# 2. Middle Deciles:
#
# * Deciles 7 and 6 show a significant drop in event rates
#
# 3. Lower Deciles:
#
# * Deciles 5 to 0 show zero events, with all predictions being non-events. These deciles collectively have a non-event rate of 100%.
#
# 4. KS Statistic:
#
# * The KS statistic, which is the maximum difference between cumulative event rates and cumulative non-event rates, is highest at Decile 8 with a value of 85.98%. This suggests that the model performs best at distinguishing between events and non-events up to this decile.
#
# * The KS value gradually decreases in the following deciles, indicating a decrease in model performance for distinguishing between events and non-events.
#
# **KS Value**
#
# The highest KS value is 85.98%, found at Decile 8. This indicates that the model's performance in distinguishing between events and non-events is most significant at this decile. (If KS is in top 3 decile and score above 40, it is considered a good predictive model.)

# %%
gini_coefficient = 2 * area - 1
print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.9836668513703037
# Gini Coefficient: 0.9673337027406075

# %% [markdown]
# AUC of 0.98: The model is very good at distinguishing between events and non-events.
#
# Gini coefficient of 0.96: This further confirms that the model is highly effective in its predictions, with almost perfect rank ordering capability.
#
# The Gini coefficient ranges from -1 to 1, where a value closer to 1 signifies a perfect model, 0 indicates a model with no discriminative power, and -1 signifies a perfectly incorrect model.

# %% [markdown]
# #### Finalize The Model and Visualize Feature Importance

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
X_train_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
#
#        credit_utilization_ratio  loan_to_income_ratio  delinquency_ratio  \
# 12746                     0.364                 0.415              0.132
# 32495                     0.051                 0.307              0.062
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                  True                  False
# 32495                    0.620                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                   False               True                  False
# 32495                    True              False                  False
#
#        loan_type_Unsecured
# 12746                False
# 32495                False

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income_ratio', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income_ratio', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income_ratio', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
from joblib import dump

model_data = { 
    "model" : final_model,
    "features" : X_train_encoded.columns, 
    "scaler": scaler,
    "cols_to_scale": cols_to_scale
}

dump(model_data, "artifacts/model_data.joblib")
# Out:
# ['artifacts/model_data.joblib']
